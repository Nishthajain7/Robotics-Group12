# %%
import import_ipynb
import MilitaryRoboticSystemMaintenance
import RoboticSystemModel as rsm
# Out:
# 2025-10-08 09:44:29.485494: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 09:44:29.493018: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 09:44:29.511478: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759896869.537641   25998 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759896869.543578   25998 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759896869.561699   25998 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759896869.561731   25998 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759896869.561734   25998 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759896869.561737   25998 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-08 09:44:29.567612: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
maintenance_system = MilitaryRoboticSystemMaintenance.MilitaryRoboticSystemMaintenance()
data = maintenance_system.generate_synthetic_data()
X_train, X_test, y_train, y_test = maintenance_system.preprocess_data(data)
maintenance_system.train_model(X_train, y_train)
maintenance_system.evaluate_model(X_test, y_test)
maintenance_system.verify_with_gru(X_train, X_test, y_train, y_test)
print("Analyzing feature importance...")
maintenance_system.analyze_feature_importance()
print("Generating correlation heatmap...")
maintenance_system.correlation_heatmap(data)
print("Generating feature distribution plots...")
maintenance_system.feature_distribution(data)
print("Generating time series plot...")
maintenance_system.time_series_plot(data)
predictions = maintenance_system.predict_maintenance_needs(data)
robot = rsm.RoboticSystemModel(data)
tasks = [
{'name': 'Surveillance', 'position': [5, 10, 15]},
{'name': 'Logistics', 'position': [10, 5, 20]},
{'name': 'Reconnaissance', 'position': [20, 15, 5]},
{'name': 'Combat Support', 'position': [25, 10, 10]},
{'name': 'Maintenance Check', 'position': [0, 0, 0]}]
robot.analyze_tasks(tasks)
print(predictions.head(10))
print("Creating 3D visualization of failure risks...")
rsm.RoboticSystemModel.visualize_3d_risk(data)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70       192
#            1       0.47      0.46      0.47       108
#
#     accuracy                           0.62       300
#    macro avg       0.59      0.59      0.59       300
# weighted avg       0.62      0.62      0.62       300
# Epoch 1/30
# /home/nishtha/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5357 - loss: 0.6890 - val_accuracy: 0.6071 - val_loss: 0.6743
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5696 - loss: 0.6811 - val_accuracy: 0.6286 - val_loss: 0.6699
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5893 - loss: 0.6683 - val_accuracy: 0.6143 - val_loss: 0.6678
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6268 - loss: 0.6596 - val_accuracy: 0.6071 - val_loss: 0.6687
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6054 - loss: 0.6574 - val_accuracy: 0.5786 - val_loss: 0.6697
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6499 - val_accuracy: 0.5857 - val_loss: 0.6730
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6339 - loss: 0.6471 - val_accuracy: 0.5786 - val_loss: 0.6737
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6196 - loss: 0.6511 - val_accuracy: 0.5857 - val_loss: 0.6736
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6402 - val_accuracy: 0.5929 - val_loss: 0.6756
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6429 - loss: 0.6393 - val_accuracy: 0.5857 - val_loss: 0.6778
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6411 - loss: 0.6416 - val_accuracy: 0.5571 - val_loss: 0.6790
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6571 - loss: 0.6401 - val_accuracy: 0.5786 - val_loss: 0.6815
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6625 - loss: 0.6338 - val_accuracy: 0.5714 - val_loss: 0.6835
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6732 - loss: 0.6188 - val_accuracy: 0.5571 - val_loss: 0.6846
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6732 - loss: 0.6192 - val_accuracy: 0.5714 - val_loss: 0.6876
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6661 - loss: 0.6211 - val_accuracy: 0.6000 - val_loss: 0.6892
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6750 - loss: 0.6177 - val_accuracy: 0.6000 - val_loss: 0.6900
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6768 - loss: 0.6194 - val_accuracy: 0.5786 - val_loss: 0.6928
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6786 - loss: 0.6159 - val_accuracy: 0.6000 - val_loss: 0.6940
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6875 - loss: 0.6039 - val_accuracy: 0.5929 - val_loss: 0.6929
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6893 - loss: 0.6094 - val_accuracy: 0.6000 - val_loss: 0.6996
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6714 - loss: 0.6069 - val_accuracy: 0.6143 - val_loss: 0.7031
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6964 - loss: 0.6115 - val_accuracy: 0.6000 - val_loss: 0.6965
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7125 - loss: 0.6032 - val_accuracy: 0.6143 - val_loss: 0.6989
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6964 - loss: 0.5945 - val_accuracy: 0.5857 - val_loss: 0.7017
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7036 - loss: 0.6034 - val_accuracy: 0.6214 - val_loss: 0.7063
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7107 - loss: 0.5919 - val_accuracy: 0.6214 - val_loss: 0.7094
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6857 - loss: 0.5844 - val_accuracy: 0.6000 - val_loss: 0.7111
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6982 - loss: 0.5972 - val_accuracy: 0.5929 - val_loss: 0.7154
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7018 - loss: 0.5816 - val_accuracy: 0.6000 - val_loss: 0.7140
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# ✅ GRU Model Evaluation:
# Accuracy: 0.5867
# F1 Score: 0.3034
#
# 📊 Random Forest vs GRU Comparison:
# Random Forest - Accuracy: 0.6200, F1: 0.4673
# GRU Model     - Accuracy: 0.5867, F1: 0.3034
# Analyzing feature importance...
# Generating correlation heatmap...
# Generating feature distribution plots...
# Generating time series plot...
# Starting task: Surveillance
#
# ============================================================
# MOVEMENT OPERATION - Row #0
# ============================================================
# Initial System Metrics:
#   Temperature: 368.73°C
#   Voltage: 0.17 V
#   Current: 21.44 A
#
# Moving from [0, 0, 0] to [5, 10, 15]...
# Position updated: [5, 10, 15]
# Remaining Battery Level: 98.13%
# Temperature: 368.73°C
# Voltage Fluctuation: 0.17 V
# Current Draw: 21.44 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (368.73°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Surveillance - Row #1
# ============================================================
# Executing task: Surveillance...
# Task 'Surveillance' execution completed.
# Remaining Battery Level: 93.13%
# Hydraulic Pressure: 1493.96 kPa
# Load Capacity: 51.21%
# System Vibration: 2.38 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #1
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (397.54°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Excessive System Vibration (2.38 mm/s > 2.0 mm/s)
#
# System Status: Maintenance Required
#
# Starting task: Logistics
#
# ============================================================
# MOVEMENT OPERATION - Row #2
# ============================================================
# Initial System Metrics:
#   Temperature: 386.60°C
#   Voltage: -0.25 V
#   Current: 25.20 A
#
# Moving from [5, 10, 15] to [10, 5, 20]...
# Position updated: [10, 5, 20]
# Remaining Battery Level: 92.26%
# Temperature: 386.60°C
# Voltage Fluctuation: -0.25 V
# Current Draw: 25.20 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #2
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (386.60°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Excessive Power Unit Vibration (2.64 mm/s > 2.5 mm/s)
#   4. High Operational Hours (4272.74 > 4000 hours)
#   5. High Duty Cycle (81.07% > 80%)
#   6. Hydraulic Pressure Out of Range (2812.51 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Logistics - Row #3
# ============================================================
# Executing task: Logistics...
# Task 'Logistics' execution completed.
# Remaining Battery Level: 87.26%
# Hydraulic Pressure: 1499.09 kPa
# Load Capacity: 86.01%
# System Vibration: 1.54 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #3
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (379.93°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Overdue Maintenance (336.74 days > 300 days)
#
# System Status: Maintenance Required
#
# Starting task: Reconnaissance
#
# ============================================================
# MOVEMENT OPERATION - Row #4
# ============================================================
# Initial System Metrics:
#   Temperature: 357.80°C
#   Voltage: 0.07 V
#   Current: 12.98 A
#
# Moving from [10, 5, 20] to [20, 15, 5]...
# Position updated: [20, 15, 5]
# Remaining Battery Level: 85.20%
# Temperature: 357.80°C
# Voltage Fluctuation: 0.07 V
# Current Draw: 12.98 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #4
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (357.80°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. High Operational Hours (4348.25 > 4000 hours)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Reconnaissance - Row #5
# ============================================================
# Executing task: Reconnaissance...
# Task 'Reconnaissance' execution completed.
# Remaining Battery Level: 80.20%
# Hydraulic Pressure: 2518.80 kPa
# Load Capacity: 62.61%
# System Vibration: 0.47 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #5
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (357.80°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. High Duty Cycle (87.36% > 80%)
#
# System Status: Maintenance Required
#
# Starting task: Combat Support
#
# ============================================================
# MOVEMENT OPERATION - Row #6
# ============================================================
# Initial System Metrics:
#   Temperature: 352.90°C
#   Voltage: 0.41 V
#   Current: 17.22 A
#
# Moving from [20, 15, 5] to [25, 10, 10]...
# Position updated: [25, 10, 10]
# Remaining Battery Level: 79.34%
# Temperature: 352.90°C
# Voltage Fluctuation: 0.41 V
# Current Draw: 17.22 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #6
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (352.90°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. High Voltage Fluctuation (0.41 V)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Combat Support - Row #7
# ============================================================
# Executing task: Combat Support...
# Task 'Combat Support' execution completed.
# Remaining Battery Level: 74.34%
# Hydraulic Pressure: 2553.42 kPa
# Load Capacity: 40.01%
# System Vibration: 2.18 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #7
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (393.31°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Excessive System Vibration (2.18 mm/s > 2.0 mm/s)
#   4. Excessive Power Unit Vibration (2.58 mm/s > 2.5 mm/s)
#   5. High Operational Hours (4237.74 > 4000 hours)
#   6. High Voltage Fluctuation (-0.49 V)
#
# System Status: Maintenance Required
#
# Starting task: Maintenance Check
#
# ============================================================
# MOVEMENT OPERATION - Row #8
# ============================================================
# Initial System Metrics:
#   Temperature: 380.06°C
#   Voltage: 0.17 V
#   Current: 23.59 A
#
# Moving from [25, 10, 10] to [0, 0, 0]...
# Position updated: [0, 0, 0]
# Remaining Battery Level: 71.46%
# Temperature: 380.06°C
# Voltage Fluctuation: 0.17 V
# Current Draw: 23.59 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #8
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (380.06°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Hydraulic Pressure Out of Range (1130.73 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Maintenance Check - Row #9
# ============================================================
# Executing task: Maintenance Check...
# Task 'Maintenance Check' execution completed.
# Remaining Battery Level: 66.46%
# Hydraulic Pressure: 1975.14 kPa
# Load Capacity: 52.49%
# System Vibration: 1.80 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #9
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (385.40°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. High Voltage Fluctuation (-0.45 V)
#
# System Status: Maintenance Required
# Tasks where failure occurred: ['Surveillance', 'Logistics', 'Reconnaissance', 'Combat Support', 'Maintenance Check']
#    Failure_Probability Risk_Level
# 0             0.146000        Low
# 1             0.384615     Medium
# 2             0.700000       High
# 3             0.217436        Low
# 4             0.000000        NaN
# 5             0.250000        Low
# 6             0.090256        Low
# 7             0.375000     Medium
# 8             0.000000        NaN
# 9             0.000000        NaN
# Creating 3D visualization of failure risks...
