# %%
import import_ipynb
import MilitaryRoboticSystemMaintenance
import RoboticSystemModel as rsm
# Out:
# 2025-10-08 20:39:53.374180: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 20:39:53.379461: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 20:39:53.393847: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759936193.417822   57116 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759936193.425942   57116 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759936193.444311   57116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759936193.444348   57116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759936193.444352   57116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759936193.444356   57116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-08 20:39:53.451180: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1000

# %%
maintenance_system = MilitaryRoboticSystemMaintenance.MilitaryRoboticSystemMaintenance()
data = maintenance_system.generate_synthetic_data()
X_train, X_test, y_train, y_test = maintenance_system.preprocess_data(data)
maintenance_system.train_model(X_train, y_train)
maintenance_system.evaluate_model(X_test, y_test)
maintenance_system.verify_with_gru(X_train, X_test, y_train, y_test)
print("Analyzing feature importance...")
maintenance_system.analyze_feature_importance()
print("Generating correlation heatmap...")
maintenance_system.correlation_heatmap(data)
print("Generating feature distribution plots...")
maintenance_system.feature_distribution(data)
print("Generating time series plot...")
maintenance_system.time_series_plot(data)
predictions = maintenance_system.predict_maintenance_needs(data)
robot = rsm.RoboticSystemModel(data)
tasks = [
{'name': 'Surveillance', 'position': [5, 10, 15]},
{'name': 'Logistics', 'position': [10, 5, 20]},
{'name': 'Reconnaissance', 'position': [20, 15, 5]},
{'name': 'Combat Support', 'position': [25, 10, 10]},
{'name': 'Maintenance Check', 'position': [0, 0, 0]}]
robot.analyze_tasks(tasks)
print(predictions.head(10))
print("Creating 3D visualization of failure risks...")
rsm.RoboticSystemModel.visualize_3d_risk(data)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       207
#            1       1.00      1.00      1.00        93
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
# Epoch 1/30
# 2025-10-08 20:40:06.572488: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nishtha/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6554 - loss: 0.6646 - val_accuracy: 0.9214 - val_loss: 0.5832
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9286 - loss: 0.5312 - val_accuracy: 0.9429 - val_loss: 0.4557
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9429 - loss: 0.4026 - val_accuracy: 0.9500 - val_loss: 0.3302
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9464 - loss: 0.2889 - val_accuracy: 0.9500 - val_loss: 0.2381
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9500 - loss: 0.2044 - val_accuracy: 0.9500 - val_loss: 0.1809
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.1581 - val_accuracy: 0.9500 - val_loss: 0.1464
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.1341 - val_accuracy: 0.9571 - val_loss: 0.1265
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1067 - val_accuracy: 0.9571 - val_loss: 0.1105
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0957 - val_accuracy: 0.9643 - val_loss: 0.1001
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0906 - val_accuracy: 0.9500 - val_loss: 0.1001
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0876 - val_accuracy: 0.9643 - val_loss: 0.0894
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9768 - loss: 0.0805 - val_accuracy: 0.9643 - val_loss: 0.0912
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.0781 - val_accuracy: 0.9643 - val_loss: 0.0828
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9804 - loss: 0.0672 - val_accuracy: 0.9714 - val_loss: 0.0764
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.0670 - val_accuracy: 0.9643 - val_loss: 0.0848
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9679 - loss: 0.0725 - val_accuracy: 0.9571 - val_loss: 0.0779
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0675 - val_accuracy: 0.9643 - val_loss: 0.0742
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0694 - val_accuracy: 0.9500 - val_loss: 0.0695
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9732 - loss: 0.0618 - val_accuracy: 0.9500 - val_loss: 0.0813
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9786 - loss: 0.0574 - val_accuracy: 0.9643 - val_loss: 0.0769
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9786 - loss: 0.0611 - val_accuracy: 0.9571 - val_loss: 0.0742
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9768 - loss: 0.0641 - val_accuracy: 0.9643 - val_loss: 0.0740
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9821 - loss: 0.0563 - val_accuracy: 0.9643 - val_loss: 0.0780
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.0591 - val_accuracy: 0.9500 - val_loss: 0.0739
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.0573 - val_accuracy: 0.9571 - val_loss: 0.0700
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9857 - loss: 0.0590 - val_accuracy: 0.9571 - val_loss: 0.0818
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9786 - loss: 0.0569 - val_accuracy: 0.9643 - val_loss: 0.0655
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0576 - val_accuracy: 0.9643 - val_loss: 0.0713
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.0556 - val_accuracy: 0.9714 - val_loss: 0.0635
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9786 - loss: 0.0553 - val_accuracy: 0.9571 - val_loss: 0.0677
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# ✅ GRU Model Evaluation:
# Accuracy: 0.9700
# F1 Score: 0.9514
#
# 📊 Random Forest vs GRU Comparison:
# Random Forest - Accuracy: 1.0000, F1: 1.0000
# GRU Model     - Accuracy: 0.9700, F1: 0.9514
# Analyzing feature importance...
# Generating correlation heatmap...
# Generating feature distribution plots...
# Generating time series plot...
# Starting task: Surveillance
#
# ============================================================
# MOVEMENT OPERATION - Row #0
# ============================================================
# Initial System Metrics:
#   Temperature: 368.73°C
#   Current: 4.73 A
#
# Moving from [0, 0, 0] to [5, 10, 15]...
# Position updated: [5, 10, 15]
# Remaining Battery Level: 98.13%
# Temperature: 368.73°C
# Current Draw: 4.73 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (368.73°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (2.921446485352181 > 2)
#   4. Hydraulic Pressure Out of Range (7.79 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Surveillance - Row #1
# ============================================================
# Executing task: Surveillance...
# Task 'Surveillance' execution completed.
# Remaining Battery Level: 93.13%
# Hydraulic Pressure: 7.74 kPa
# System Vibration: 0.96 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #1
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (397.54°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Hydraulic Pressure Out of Range (7.74 kPa)
#
# System Status: Maintenance Required
#
# Starting task: Logistics
#
# ============================================================
# MOVEMENT OPERATION - Row #2
# ============================================================
# Initial System Metrics:
#   Temperature: 386.60°C
#   Current: 4.83 A
#
# Moving from [5, 10, 15] to [10, 5, 20]...
# Position updated: [10, 5, 20]
# Remaining Battery Level: 92.26%
# Temperature: 386.60°C
# Current Draw: 4.83 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #2
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (386.60°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Hydraulic Pressure Out of Range (9.72 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Logistics - Row #3
# ============================================================
# Executing task: Logistics...
# Task 'Logistics' execution completed.
# Remaining Battery Level: 87.26%
# Hydraulic Pressure: 7.75 kPa
# System Vibration: 0.64 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #3
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (379.93°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (9.717120953891037 > 2)
#   4. Hydraulic Pressure Out of Range (7.75 kPa)
#
# System Status: Maintenance Required
#
# Starting task: Reconnaissance
#
# ============================================================
# MOVEMENT OPERATION - Row #4
# ============================================================
# Initial System Metrics:
#   Temperature: 357.80°C
#   Current: 6.25 A
#
# Moving from [10, 5, 20] to [20, 15, 5]...
# Position updated: [20, 15, 5]
# Remaining Battery Level: 85.20%
# Temperature: 357.80°C
# Current Draw: 6.25 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #4
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (357.80°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (2.95633685837714 > 2)
#   4. Hydraulic Pressure Out of Range (7.82 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Reconnaissance - Row #5
# ============================================================
# Executing task: Reconnaissance...
# Task 'Reconnaissance' execution completed.
# Remaining Battery Level: 80.20%
# Hydraulic Pressure: 9.28 kPa
# System Vibration: 0.24 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #5
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (357.80°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (5.187906217433661 > 2)
#   4. Hydraulic Pressure Out of Range (9.28 kPa)
#
# System Status: Maintenance Required
#
# Starting task: Combat Support
#
# ============================================================
# MOVEMENT OPERATION - Row #6
# ============================================================
# Initial System Metrics:
#   Temperature: 352.90°C
#   Current: 4.26 A
#
# Moving from [20, 15, 5] to [25, 10, 10]...
# Position updated: [25, 10, 10]
# Remaining Battery Level: 79.34%
# Temperature: 352.90°C
# Current Draw: 4.26 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #6
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (352.90°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (2.3763754399239962 > 2)
#   4. Hydraulic Pressure Out of Range (8.35 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Combat Support - Row #7
# ============================================================
# Executing task: Combat Support...
# Task 'Combat Support' execution completed.
# Remaining Battery Level: 74.34%
# Hydraulic Pressure: 9.33 kPa
# System Vibration: 0.88 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #7
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (393.31°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (7.3521611924077215 > 2)
#   4. Hydraulic Pressure Out of Range (9.33 kPa)
#
# System Status: Maintenance Required
#
# Starting task: Maintenance Check
#
# ============================================================
# MOVEMENT OPERATION - Row #8
# ============================================================
# Initial System Metrics:
#   Temperature: 380.06°C
#   Current: 7.51 A
#
# Moving from [25, 10, 10] to [0, 0, 0]...
# Position updated: [0, 0, 0]
# Remaining Battery Level: 71.46%
# Temperature: 380.06°C
# Current Draw: 7.51 A
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ MOVEMENT FAILURE DETECTED - Row #8
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (380.06°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (7.853406511139436 > 2)
#   4. Hydraulic Pressure Out of Range (7.20 kPa)
#
# System Status: Maintenance Required
#
# ============================================================
# TASK EXECUTION: Maintenance Check - Row #9
# ============================================================
# Executing task: Maintenance Check...
# Task 'Maintenance Check' execution completed.
# Remaining Battery Level: 66.46%
# Hydraulic Pressure: 8.46 kPa
# System Vibration: 0.74 mm/s
# Power Unit Temperature: 400.00°C
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ⚠️ TASK FAILURE DETECTED - Row #9
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Failure Reasons:
#   1. High System Temperature (385.40°C > 70°C)
#   2. High Power Unit Temperature (400.00°C > 80°C)
#   3. Multiple Previous Failures (4.8674215295945515 > 2)
#   4. Hydraulic Pressure Out of Range (8.46 kPa)
#
# System Status: Maintenance Required
# Tasks where failure occurred: ['Surveillance', 'Logistics', 'Reconnaissance', 'Combat Support', 'Maintenance Check']
#    Failure_Probability Risk_Level
# 0             0.004912        Low
# 1             0.976723       High
# 2             0.124304        Low
# 3             0.001538        Low
# 4             0.000000        NaN
# 5             0.000000        NaN
# 6             0.000000        NaN
# 7             0.995833       High
# 8             0.002593        Low
# 9             0.958074       High
# Creating 3D visualization of failure risks...
