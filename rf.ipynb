# %%
import import_ipynb
import MilitaryRoboticMaintenance
import RoboticSystemModel as rsm
# Out:
# 2025-10-15 17:01:21.047424: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-15 17:01:21.053218: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-15 17:01:21.065790: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760527881.088717   54504 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760527881.094236   54504 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
maintenance_system = MilitaryRoboticMaintenance.MilitaryRoboticMaintenance()
data = maintenance_system.generate_synthetic_data()
X_train, X_test, y_train, y_test, y_rul_train, y_rul_test = maintenance_system.preprocess_data(data)
maintenance_system.optimize_rf_with_optuna(X_train, y_train, n_trials=30)
maintenance_system.train_optimized_rf(X_train, y_train)
history_att, X_test_seq = maintenance_system.train_deep_models(X_train, X_test, y_train, y_test, epochs=30)
results = maintenance_system.evaluate_all_models(X_test, X_test_seq, y_test, n_runs=5)
maintenance_system.plot_pr_curves(X_test, X_test_seq, y_test)
rul_model = maintenance_system.estimate_rul(X_test, y_rul_test)
maintenance_system.shap_analysis(X_test)
maintenance_system.pca_visualization(X_test, y_test)
data2 = maintenance_system.generate_synthetic_data(n_samples=500)
maintenance_system.cross_dataset_validation(data, data2)

# maintenance_system.verify_with_gru(X_train, X_test, y_train, y_test)
# print("Analyzing feature importance...")
# maintenance_system.analyze_feature_importance()
# print("Generating correlation heatmap...")
# maintenance_system.correlation_heatmap(data)
# print("Generating feature distribution plots...")
# maintenance_system.feature_distribution(data)
# print("Generating time series plot...")
# maintenance_system.time_series_plot(data)
# predictions = maintenance_system.predict_maintenance_needs(data)
# robot = rsm.RoboticSystemModel(data)
# tasks = [
# {'name': 'Surveillance', 'position': [5, 10, 15]},
# {'name': 'Logistics', 'position': [10, 5, 20]},
# {'name': 'Reconnaissance', 'position': [20, 15, 5]},
# {'name': 'Combat Support', 'position': [25, 10, 10]},
# {'name': 'Maintenance Check', 'position': [0, 0, 0]}]
# robot.analyze_tasks(tasks)
# print(predictions.head(10))
# print("Creating 3D visualization of failure risks...")
# rsm.RoboticSystemModel.visualize_3d_risk(data)
# Out:
# [I 2025-10-15 17:01:23,795] A new study created in memory with name: RF_optimization
# 🔍 Starting Bayesian Optimization with Optuna...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-10-15 17:01:25,791] Trial 0 finished with value: 0.18410347416558598 and parameters: {'n_estimators': 152, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.18410347416558598.
# [I 2025-10-15 17:01:26,774] Trial 1 finished with value: 0.23085433085433085 and parameters: {'n_estimators': 57, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.23085433085433085.
# [I 2025-10-15 17:01:28,158] Trial 2 finished with value: 0.29885603757944185 and parameters: {'n_estimators': 267, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 2 with value: 0.29885603757944185.
# ...
